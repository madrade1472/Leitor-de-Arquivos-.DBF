# %%
import pandas as pd
import dbf

# %%
thisTable = dbf.Table('C:/Users/29086/Downloads/FFF_BRA_PM_PPP_EUF_202207/PM_PPP_PACK.DBF')

# %%
thisTable.open(mode=dbf.READ_ONLY)
# Out:
# dbf.Table('C:/Users/29086/Downloads/FFF_BRA_PM_PPP_EUF_202207/PM_PPP_PACK.DBF', status=<DbfStatus.READ_ONLY: 1>)

# %%
thisTable.open()
# Out:
# dbf.Table('C:/Users/29086/Downloads/FFF_BRA_PM_PPP_EUF_202207/PM_PPP_PACK.DBF', status=<DbfStatus.READ_ONLY: 1>)

# %%
print(thisTable)
# Out:
#         Table:         C:/Users/29086/Downloads/FFF_BRA_PM_PPP_EUF_202207/PM_PPP_PACK.DBF
#         Type:          dBase III Plus
#         Codepage:      cp437 (U.S. MS-DOS)
#         Status:        DbfStatus.READ_ONLY
#         Last updated:  1917-10-11
#         Record count:  45257
#         Field count:   12
#         Record length: 164
#         --Fields--
#           0) b'PACKCODE C(7)'
#           1) b'PRODCODE C(5)'
#           2) b'FCC_COD C(10)'
#           3) b'PACK_DES C(90)'
#           4) b'PACK_LNCH C(8)'
#           5) b'MARK_COD C(1)'
#           6) b'GENE_COD C(1)'
#           7) b'STD_FACT N(9,4)'
#           8) b'DSG_FACT N(9,4)'
#           9) b'CLASS4_COD C(5)'
#          10) b'APP3_COD C(3)'
#          11) b'BRIDGE_COD C(15)'

# %%
thisTable = pd.DataFrame(thisTable,columns = ['a', 'b', 'c','d','e','f','g','h','i','j','k','l'])

# %%
thisTable
# Out:
#              a      b           c  \
# 0      0000101  00001  0000060224
# 1      0000501  00005  0000060229
# 2      0000703  00007  0000178089
# 3      0000704  00007  0000178090
# 4      0000705  00007  0000208468
# ...        ...    ...         ...
# 45252  9390920  93909  0000057214
# 45253  9390940  93909  0000057215
# 45254  9391915  93919  0000059386
# 45255  9392920  93929  0000059387
# 45256  9393930  93939  0000059388
#
#                                                        d         e  f  g  \
# 0      ALPHAGAN P SOL OFTAL 0.15 % 5 ML x 1          ...  20020801  E  R
# 1      BACINANTRAT POMADA 5MG/ 250 IU 10 G x 1 (/G)  ...  19980401  E  M
# 2      COMPLEXIMED B DRAG x 50                       ...  20150701  P  M
# 3      COMPLEXIMED B DRAG x 100                      ...  20150701  P  M
# 4      COMPLEXIMED B GOTAS 30 ML x 1                 ...  20170201  P  M
# ...                                                  ...       ... .. ..
# ...
